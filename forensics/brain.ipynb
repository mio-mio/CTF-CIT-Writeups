# %% [markdown]
# <a href="https://colab.research.google.com/github/mio-mio/CTF-CIT-Writeups/blob/main/forensics/brain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Brainrot Quiz!

# %% [markdown]
# ![スクリーンショット 2025-04-30 21.06.55.png](data:image/png;base64,...)

# %% [markdown]
# ## Challenge Overview
# - **Category:** Forensics
# - **Challenge Name:** Brainrot Quiz!
#
# ## Description
# - **Challenge Text:**
#   Bombardiro Crocodillo or....? You find out...
# - **Attachement:** brainrot.pcap
#
# ## Initial Analysis
# - The file extension is `pcap`, wireshark will be useful.
#
# ## Attempts and Progress
# - Appeared 30 ICMP communications and No.11 and No.19 had bigger number in length compared to other comunications.
# - Checked the data in Internet Control message Protocol and found suspicious strings.

# %% [markdown]
# ![スクリーンショット 2025-04-30 21.28.21.png](data:image/png;base64,...)

# %% [markdown]
# ## Solution
# - While reviewing other sources, the suspicous strings can be decoded by BASE64 and leads to the flag.
#
# ## Reflection
# - Correct tool was chosen for the task.
# - Suspicious string was identified but not followed up with enough decoding attempts.
# - Will approach similar cases more patiently in the future.
