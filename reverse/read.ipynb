# %% [markdown]
# <a href="https://colab.research.google.com/github/mio-mio/CTF-CIT-Writeups/blob/main/reverse/read.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Read Only

# %% [markdown]
# ![スクリーンショット 2025-04-29 15.27.27.png](data:image/png;base64,...)

# %% [markdown]
# ## Challenge Overview
# - **Category:** Reverse Engineering
# - **Challenge Name:** Read Only
#
# ## Description
# - **Challenge Text:**
#   Here we go!
#   **Data:** readonly
#
# ## Initial Analysis
# - Used the `file` command to confirm it was a 64-bit executable.
# - The name “Read Only” suggested the program might output a fixed string or restrict input in some way.
#
#
# ## Attempts and Progress
# - Used `strings readonly | less` and search manually, but the output was too long to find anything by eye.
#
#
# ## Solution

# %% [markdown]
# ![スクリーンショット 2025-04-30 13.52.37.png](data:image/png;base64,...)

# %% [markdown]
# - Opend the file with `BinaryNinja` and used the search function to locate the flag.
#
# ## Reflection
# - First reversing challenge in this CTF; learned to start with basic tools like `strings` and `file``.
# - It was satisfying to uncover the program's logic through analysis.
