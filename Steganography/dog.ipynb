# %% [markdown]
# <a href="https://colab.research.google.com/github/mio-mio/CTF-CIT-Writeups/blob/main/Steganography/dog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dog Picture

# %% [markdown]
# ![スクリーンショット 2025-04-29 14.00.07.png](data:image/png;base64,...)

# %% [markdown]
# ## Challenge Overview
# **Title:** Dog Picture
# **Category:** Steganography
#
# ## Description
# > Forget about the flag, look at how cute that dog is!
#
# Data provided: `dogpicture.png`

# %% [markdown]
# ![dogpicture.png](data:image/png;base64,...)

# %% [markdown]
# ## Initial Analysis
#
# - Used `file dogpicture.png` to verify the file type.
#   - Result: PNG image, no issues detected.
# - Ran `strings dogpicture.png` to check for readable embedded text.
#   - No useful information found.
#
# ---
#
# ## Attempts and Progress
#  - Searched for readable strings using `grep` and analyzed least significant bits (LSB) with `zsteg`, but no hidden text was found. *Errors happened.*
#
# - Attempted file extraction with `binwalk -e` and `foremost`, yet no embedded files or recoverable fragments were identified.
#
# - Verified the image structure using `pngcheck -v`; no format issues or anomalies were detected.
#
# ## Solution

# %% [markdown]
# ![スクリーンショット 2025-04-29 13.56.59.png](data:image/png;base64,...)

# %% [markdown]
# - Learned that LSB steganography was used; extracted RGB bit 0 via Stegonline to reveal the flag in ASCII.
#   - Reference: https://www.georgeom.net/StegOnline/upload
#
#
#
#
# ---
#
# ## Reflection
# - Learned that not all steganographic challenges show clear signs through automated analysis.
# - Practiced a methodical approach that can be reused for similar challenges in the future.
#
# ---
