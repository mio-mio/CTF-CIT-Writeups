# %% [markdown]
# <a href="https://colab.research.google.com/github/mio-mio/writeups/blob/main/misc/calc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Misc - Calculator

# %% [markdown]
# ![スクリーンショット 2025-04-27 18.41.47.png](data:image/png;base64,...)

# %% [markdown]
# ## Challenge Overview
#
#
# **Title:** Calculator
# **Category:** Misc
#
# ## Description
# > Find the flag.
#
# Provided data: `calculator.lua`

# %% [markdown]
# ![スクリーンショット 2025-04-27 19.15.07.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ## Initial Analysis
# - Opened the file in VS code to examine the contents.
#
# ## Attempts and Progress
# - Observed that the Lua script appeared to define a basic calculator.
# - Functions for addition, subtraction, multiplication, and division were present.
# - Checked if any hidden functions or strange comments were embedded in the script and found "-- nope no flag here, keep looking :P" at the end of the script.
# - Searched for suspicious strings inside the code.
# - Attempted basic searches like:
#   - `strings calculator.lua`
#   - `grep` for keywords like `flag`, `{`, `CIT`, `FLAG`
# - No immediate signs of the flag were found.
# - Also considered:
#   - Running the script to see if any non-standard behavior occurred
#   - Modifying inputs to the calculator to see if unusual outputs (e.g., hidden messages) would appear
#
# ## Solution

# %% [markdown]
# ![スクリーンショット 2025-04-27 19.16.37.png](data:image/png;base64,...)

# %% [markdown]
# - While reviewing further information, learned that the script contained suspicious lines before the message "-- nope no flag here, keep looking :P".
#
# - These lines were written in **Whitespace Language**, a form of steganography using spaces and tabs.
#
# - After decoding the hidden content, the flag was successfully recovered.
#
#
# ---
#
# ## Reflection
# - This was my first time handling Lua files and Whitespace Language.
# - Learned the importance of not just reading code superficially but thinking about "hidden" things.
