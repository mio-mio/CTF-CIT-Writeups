# %% [markdown]
# <a href="https://colab.research.google.com/github/mio-mio/writeups/blob/main/misc/robots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Robots

# %% [markdown]
# ![スクリーンショット 2025-04-27 22.27.34.png](data:image/png;base64,...)

# %% [markdown]
# ## Challenge Overview
# - **Title:** Robots
# - **Category:** Misc
#
# ## Description
# - **Challenge Text:**  Beep boop
#
#
#
# ## Initial Analysis
# - The phrase "Beep boop" loosely suggested something related to robots or those sound.
#
# ## Attempts and Progress
# - Without any clear leads, various general searches about "robots" were attempted.
# - Looked into concepts like robots in cybersecurity, automated files, and common robot-related terms.
#
# ## Solution
# - While reviewing additional information, learned that the intended solution involved accessing the event website's `robots.txt` file.
# - Manually added `/robots.txt` to the official event URL:
#   `https://ctf.cyber-cit.club/robots.txt`
# - By inspecting the content of that file and searching for "CIT," the hidden flag information was found.

# %% [markdown]
# ![スクリーンショット 2025-04-27 22.41.23.png](data:image/png;base64,...)

# %% [markdown]
# ## Reflection
# - During the event, I had no idea how to approach this challenge.
# - I later learned that checking for a `robots.txt` file on the event website would reveal hidden information.
# - I was surprised to discover that such a simple idea could lead to the solution, as I had no prior knowledge of basic web reconnaissance techniques.
# - This challenge made me realize the importance of learning even fundamental web exploration methods, which I had not been aware of before.
