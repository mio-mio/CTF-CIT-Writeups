# %% [markdown]
# <a href="https://colab.research.google.com/github/mio-mio/writeups/blob/main/osint/apizza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OSINT - Apizza

# %% [markdown]
# ![スクリーンショット 2025-04-27 19.03.17.png](data:image/png;base64,...)

# %% [markdown]
# ## Challenge Overview
# **Title:** Apizza
# **Category:** OSINT
#
# ## Description
# > Everyone always talks about how good New Haven style pizza is.
# > It's the kind of pizza you simply feel in your bones afterwards.
#
# Provided data: `Apizza.PNG`

# %% [markdown]
# ![apizza (1).png](data:image/png;base64,...)

# %% [markdown]
# ## Initial Analysis
# - Opened `Apizza.PNG`, which shows a Google Street View-style overhead photo of Frank Pepe Pizzeria Napoletana.
# - Noted that the challenge references "New Haven style pizza", suggesting local cultural information might be relevant.
#
# ## Attempts and Progress
# - Conducted research on Frank Pepe and New Haven "apizza" culture.
# - Tried obvious keywords related to Frank Pepe:
#   - frank_pepe
#   - frank_pepe_1925 (year of founding)
#   - apizza
#   - wooster_street
# - Attempted address information:
#   - 163_Wooster_Street
#   - 163WoosterSt
# - Explored event-related keywords:
#   - 100_year_anniversary
#   - frank_pepe_100_years
# - Also considered menu items and regional nicknames without success.
#
#
# ## Solution

# %% [markdown]
# ![スクリーンショット 2025-04-27 19.23.49.png](data:image/png;base64,...)

# %% [markdown]
# - While reviewing further information, learned that searching for "bones" in this area leads to finding the "Skull and Bones" society nearby.
# - The name of this society was the flag.
#
# ---
#
# ## Reflection
# - Learned that OSINT challenges sometimes require trying many small variations of culturally linked keywords and shifting perspectives.
